# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime

# %%
date  = "12/02/2021"

# %%
time=pd.to_datetime(date,dayfirst=True)

# %%
time
# Out:
# Timestamp('2021-02-12 00:00:00')

# %%
pwd
# Out:
# 'C:\\Users\\Ruhail\\Downloads'

# %%
cd Downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'Downloads'
# C:\Users\Ruhail\Downloads

# %%
pwd
# Out:
# 'C:\\Users\\Ruhail\\Downloads'

# %%
df
# Out:
#                         Report Generated By  :         Ruhail Rafiq  \
# 0                              Generated On  :  11/10/2021 11:43 PM
# 1                             Department Name:       Radianz Energy
# 2                        Ruhail-HYD-AP Closed                   NaN
# 3                                 Contact name            Ticket Id
# 4                           Decathlon Internal               217766
# ...                                        ...                  ...
# 1146                            Trent Internal               261439
# 1147                            Trent Internal               261438
# 1148                            Trent Internal               264349
# 1149                            Trent Internal               264638
# 1150  Total records in this page :1146 Records                  NaN
#
#                  Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                       NaN                  NaN                  NaN
# ...

# %%
df = pd.read_excel("ExportReport_1633976028272.xls")

# %%
df
# Out:
#                         Report Generated By  :         Ruhail Rafiq  \
# 0                              Generated On  :  11/10/2021 11:43 PM
# 1                             Department Name:       Radianz Energy
# 2                        Ruhail-HYD-AP Closed                   NaN
# 3                                 Contact name            Ticket Id
# 4                           Decathlon Internal               217766
# ...                                        ...                  ...
# 1146                            Trent Internal               261439
# 1147                            Trent Internal               261438
# 1148                            Trent Internal               264349
# 1149                            Trent Internal               264638
# 1150  Total records in this page :1146 Records                  NaN
#
#                  Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                       NaN                  NaN                  NaN
# ...

# %%
excel = df.loc[3:]

# %%
excel
# Out:
#                         Report Generated By  : Ruhail Rafiq  \
# 3                                 Contact name    Ticket Id
# 4                           Decathlon Internal       217766
# 5                           Decathlon Internal       219121
# 6                           Decathlon Internal       219606
# 7                           Decathlon Internal       219614
# ...                                        ...          ...
# 1146                            Trent Internal       261439
# 1147                            Trent Internal       261438
# 1148                            Trent Internal       264349
# 1149                            Trent Internal       264638
# 1150  Total records in this page :1146 Records          NaN
#
#                  Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 3     Created Time (Ticket)             Due Date   Ticket Closed Time
# 4       05/04/2021 09:40 AM  07/04/2021 09:40 AM  16/04/2021 12:14 AM
# ...

# %%
new_header=excel.iloc[0]

# %%
new_header
# Out:
# Report Generated By  :                   Contact name
# Ruhail Rafiq                                Ticket Id
# Unnamed: 2                      Created Time (Ticket)
# Unnamed: 3                                   Due Date
# Unnamed: 4                         Ticket Closed Time
# Unnamed: 5                     Booth No. or Store ID.
# Unnamed: 6                                   Location
# Unnamed: 7                               Issue Report
# Unnamed: 8                                    Subject
# Unnamed: 9                                    Problem
# Unnamed: 10                                 Solutions
# Unnamed: 11                                Resolution
# Unnamed: 12                        Issue Resolved by?
# Unnamed: 13                                  Visit By
# Unnamed: 14                               Issue Owner
# Unnamed: 15                                  Genuine?
# Unnamed: 16                              Ticket Owner
# ...

# %%
excel
# Out:
#                         Report Generated By  : Ruhail Rafiq  \
# 3                                 Contact name    Ticket Id
# 4                           Decathlon Internal       217766
# 5                           Decathlon Internal       219121
# 6                           Decathlon Internal       219606
# 7                           Decathlon Internal       219614
# ...                                        ...          ...
# 1146                            Trent Internal       261439
# 1147                            Trent Internal       261438
# 1148                            Trent Internal       264349
# 1149                            Trent Internal       264638
# 1150  Total records in this page :1146 Records          NaN
#
#                  Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 3     Created Time (Ticket)             Due Date   Ticket Closed Time
# 4       05/04/2021 09:40 AM  07/04/2021 09:40 AM  16/04/2021 12:14 AM
# ...

# %%
new_header = excel.iloc[0]

# %%
q1 = excel[1:]

# %%
q1.columns = new_header

# %%
q1
# Out:
# 3                                 Contact name Ticket Id  \
# 4                           Decathlon Internal    217766
# 5                           Decathlon Internal    219121
# 6                           Decathlon Internal    219606
# 7                           Decathlon Internal    219614
# 8                           Decathlon Internal    219609
# ...                                        ...       ...
# 1146                            Trent Internal    261439
# 1147                            Trent Internal    261438
# 1148                            Trent Internal    264349
# 1149                            Trent Internal    264638
# 1150  Total records in this page :1146 Records       NaN
#
# 3    Created Time (Ticket)             Due Date   Ticket Closed Time  \
# 4      05/04/2021 09:40 AM  07/04/2021 09:40 AM  16/04/2021 12:14 AM
# 5      13/04/2021 09:57 AM  15/04/2021 09:57 AM  16/04/2021 05:41 PM
# 6      15/04/2021 10:10 AM  17/04/2021 10:10 AM  16/04/2021 12:22 AM
# ...

# %%
q1.columns
# Out:
# Index(['Contact name', 'Ticket Id', 'Created Time (Ticket)', 'Due Date',
#        'Ticket Closed Time', 'Booth No. or Store ID.', 'Location',
#        'Issue Report', 'Subject', 'Problem', 'Solutions', 'Resolution',
#        'Issue Resolved by?', 'Visit By', 'Issue Owner', 'Genuine?',
#        'Ticket Owner', 'Coordinate By', 'Hardware Replaced 1',
#        'Number of hardware Replaced', 'Status (Ticket)'],
#       dtype='object', name=3)

# %%
q1['Due Date']=q1['Due Date'].fillna(0)
q1['Created Time (Ticket)']=q1['Created Time (Ticket)'].fillna(0)
# Out:
# <ipython-input-144-422907d380f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q1['Due Date']=q1['Due Date'].fillna(0)
# <ipython-input-144-422907d380f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q1['Created Time (Ticket)']=q1['Created Time (Ticket)'].fillna(0)

# %%
q1
# Out:
# 3                                 Contact name Ticket Id  \
# 4                           Decathlon Internal    217766
# 5                           Decathlon Internal    219121
# 6                           Decathlon Internal    219606
# 7                           Decathlon Internal    219614
# 8                           Decathlon Internal    219609
# ...                                        ...       ...
# 1146                            Trent Internal    261439
# 1147                            Trent Internal    261438
# 1148                            Trent Internal    264349
# 1149                            Trent Internal    264638
# 1150  Total records in this page :1146 Records       NaN
#
# 3    Created Time (Ticket)             Due Date   Ticket Closed Time  \
# 4      05/04/2021 09:40 AM  07/04/2021 09:40 AM  16/04/2021 12:14 AM
# 5      13/04/2021 09:57 AM  15/04/2021 09:57 AM  16/04/2021 05:41 PM
# 6      15/04/2021 10:10 AM  17/04/2021 10:10 AM  16/04/2021 12:22 AM
# ...

# %%
type(q1['Due Date'][12])
# Out:
# str

# %%
from datetime import datetime

# %%
def DateConversion(str):
    str = '13/04/2021 09:57 PM'
    check = str[17:19]
    if check=='PM':
        hours = int(str[11:13])+12
        
    str = str[0:6]+str[8:10]
    return Hours

# %%
DateConversion('13/04/2021 09:57 PM')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-fafd31f31a5a> in <module>
# ----> 1 DateConversion('13/04/2021 09:57 PM')
#
# <ipython-input-117-d39febce515c> in DateConversion(str)
#       4     if check=='PM':
#       5         hours = int(str[11:13])+12
# ----> 6         Hours = str(hours)
#       7
#       8     str = str[0:6]+str[8:10]
#
# TypeError: 'str' object is not callable

# %%
print(abc)
# Out:
# 2021-09-25 00:00:00
